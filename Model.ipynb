# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

df=pd.read_csv("TSLA.csv")
# print('Number of rows and columns:', df.shape)
# df.head(5)

training_set = df.iloc[:800, 1:2].values
test_set = df.iloc[800:, 1:2].values

# Feature Scaling
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(60, 800):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
#(740, 60, 1)

model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 200, batch_size = 32)

dataset_train = df.iloc[:800, 1:2]
dataset_test = df.iloc[800:, 1:2]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 519):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# print(X_test.shape)
# # (459, 60, 1)

# predicted_stock_price = model.predict(X_test)
# predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# # Visualising the results
# plt.plot(df.loc[800:, 'Date'],dataset_test.values, color = 'red', label = 'Real TESLA Stock Price')
# plt.plot(df.loc[800:, 'Date'],predicted_stock_price, color = 'blue', label = 'Predicted TESLA Stock Price')
# plt.xticks(np.arange(0,459,50))
# plt.title('TESLA Stock Price Prediction')
# plt.xlabel('Time')
# plt.ylabel('TESLA Stock Price')
# plt.legend()
# plt.show()
model.save('teslamodel.h5')
# Out:
# Epoch 1/200
# 2022-04-23 13:41:53.337329: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:53.698692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:53.773169: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:53.864165: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:53.953393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:54.043410: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:54.178806: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 13:41:54.331193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#  2/24 [=>............................] - ETA: 1s - loss: 0.3380
# 2022-04-23 13:41:54.464005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 24/24 [==============================] - 6s 80ms/step - loss: 0.0802
# Epoch 2/200
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0164
# Epoch 3/200
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0109
# Epoch 4/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0105
# Epoch 5/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0109
# Epoch 6/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0111
# Epoch 7/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0092
# Epoch 8/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0086
# Epoch 9/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0090
# Epoch 10/200
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0079
# Epoch 11/200
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0081
# Epoch 12/200
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0068
# Epoch 13/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0066
# Epoch 14/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0062
# Epoch 15/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0057
# Epoch 16/200
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0052
# Epoch 17/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0049
# Epoch 18/200
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0050
# Epoch 19/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0055
# Epoch 20/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0051
# Epoch 21/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0063
# Epoch 22/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0044
# Epoch 23/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0042
# Epoch 24/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0041
# Epoch 25/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0045
# Epoch 26/200
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0043
# Epoch 27/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0038
# Epoch 28/200
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0034
# Epoch 29/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0040
# Epoch 30/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0050
# Epoch 31/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0039
# Epoch 32/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0037
# Epoch 33/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0030
# Epoch 34/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0029
# Epoch 35/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0029
# Epoch 36/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0031
# Epoch 37/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0029
# Epoch 38/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0027
# Epoch 39/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0027
# Epoch 40/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0025
# Epoch 41/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0024
# Epoch 42/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0028
# Epoch 43/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0024
# Epoch 44/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0024
# Epoch 45/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0023
# Epoch 46/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0023
# Epoch 47/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0023
# Epoch 48/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 49/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0023
# Epoch 50/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0019
# Epoch 51/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0020
# Epoch 52/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 53/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 54/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0022
# Epoch 55/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0020
# Epoch 56/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0019
# Epoch 57/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 58/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0020
# Epoch 59/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0019
# Epoch 60/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0020
# Epoch 61/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0020
# Epoch 62/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0019
# Epoch 63/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0021
# Epoch 64/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0019
# Epoch 65/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0016
# Epoch 66/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0022
# Epoch 67/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0018
# Epoch 68/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0016
# Epoch 69/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0023
# Epoch 70/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 71/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0017
# Epoch 72/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0020
# Epoch 73/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0018
# Epoch 74/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0016
# Epoch 75/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0019
# Epoch 76/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 77/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 78/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0020
# Epoch 79/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0016
# Epoch 80/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 81/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0016
# Epoch 82/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 83/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0015
# Epoch 84/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0015
# Epoch 85/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0014
# Epoch 86/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0017
# Epoch 87/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 88/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 89/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 90/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 91/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 92/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 93/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 94/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 95/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0017
# Epoch 96/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0022
# Epoch 97/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 98/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0014
# Epoch 99/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 100/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 101/200
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0016
# Epoch 102/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 103/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 104/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 105/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0013
# Epoch 106/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 107/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0020
# Epoch 108/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 109/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0015
# Epoch 110/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 111/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 112/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 113/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 114/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 115/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 116/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 117/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 118/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 119/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0014
# Epoch 120/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 121/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 122/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 123/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 124/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 125/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 126/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 127/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 128/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 129/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 130/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 131/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 132/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0017
# Epoch 133/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0016
# Epoch 134/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 135/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 136/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 137/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 138/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 139/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 140/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 141/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 142/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 143/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0017
# Epoch 144/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 145/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 146/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 147/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 148/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 149/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 150/200
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0013
# Epoch 151/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 152/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 153/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 154/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 155/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 156/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0017
# Epoch 157/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0017
# Epoch 158/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 159/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 160/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 161/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 162/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 163/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 164/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0017
# Epoch 165/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0022
# Epoch 166/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 167/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 168/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 169/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0014
# Epoch 170/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 171/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 172/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 173/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 174/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 175/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 176/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 177/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0018
# Epoch 178/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0015
# Epoch 179/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 180/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 181/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 182/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 183/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 184/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 185/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 186/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 187/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 188/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 189/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 190/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 191/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 192/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 193/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 194/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 195/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 196/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0011
# Epoch 197/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 198/200
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 199/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 200/200
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0012
