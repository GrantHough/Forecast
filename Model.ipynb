# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas
import numpy as numpy
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

df = pandas.read_csv("AAPL.csv")

training_set = df.iloc[:1000, 1:2].values
test_set = df.iloc[1000:, 1:2].values

sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

X_train = []
y_train = []
for i in range(60, 1000):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = numpy.array(X_train), numpy.array(y_train)
X_train = numpy.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

model.fit(X_train, y_train, epochs = 100, batch_size = 32)

model.save('model.h5')
# Out:
# Epoch 1/100
# 2022-04-23 17:58:03.584639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:03.956323: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.032889: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.117109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.193356: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.278644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.413102: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-04-23 17:58:04.549829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#  1/30 [>.............................] - ETA: 1:45 - loss: 0.1607
# 2022-04-23 17:58:04.682865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 30/30 [==============================] - 6s 90ms/step - loss: 0.0301
# Epoch 2/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0053
# Epoch 3/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0047
# Epoch 4/100
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0034
# Epoch 5/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0033
# Epoch 6/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0025
# Epoch 7/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0026
# Epoch 8/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0022
# Epoch 9/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0023
# Epoch 10/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0022
# Epoch 11/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0021
# Epoch 12/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0019
# Epoch 13/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0019
# Epoch 14/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0018
# Epoch 15/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0018
# Epoch 16/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0017
# Epoch 17/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0018
# Epoch 18/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0019
# Epoch 19/100
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0016
# Epoch 20/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0016
# Epoch 21/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0016
# Epoch 22/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0015
# Epoch 23/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0015
# Epoch 24/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0015
# Epoch 25/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0015
# Epoch 26/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0015
# Epoch 27/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0015
# Epoch 28/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0015
# Epoch 29/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0014
# Epoch 30/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0013
# Epoch 31/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0013
# Epoch 32/100
# 30/30 [==============================] - 1s 49ms/step - loss: 0.0012
# Epoch 33/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0014
# Epoch 34/100
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0012
# Epoch 35/100
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0017
# Epoch 36/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0015
# Epoch 37/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0013
# Epoch 38/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0012
# Epoch 39/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0013
# Epoch 40/100
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0010
# Epoch 41/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0011
# Epoch 42/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0011
# Epoch 43/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0012
# Epoch 44/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0010
# Epoch 45/100
# 30/30 [==============================] - 1s 50ms/step - loss: 9.3713e-04
# Epoch 46/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0010
# Epoch 47/100
# 30/30 [==============================] - 1s 50ms/step - loss: 9.6799e-04
# Epoch 48/100
# 30/30 [==============================] - 2s 52ms/step - loss: 8.5999e-04
# Epoch 49/100
# 30/30 [==============================] - 2s 51ms/step - loss: 9.3656e-04
# Epoch 50/100
# 30/30 [==============================] - 1s 50ms/step - loss: 9.1688e-04
# Epoch 51/100
# 30/30 [==============================] - 2s 50ms/step - loss: 9.4702e-04
# Epoch 52/100
# 30/30 [==============================] - 2s 51ms/step - loss: 9.7487e-04
# Epoch 53/100
# 30/30 [==============================] - 2s 51ms/step - loss: 9.6148e-04
# Epoch 54/100
# 30/30 [==============================] - 1s 50ms/step - loss: 7.8572e-04
# Epoch 55/100
# 30/30 [==============================] - 2s 51ms/step - loss: 9.3828e-04
# Epoch 56/100
# 30/30 [==============================] - 1s 49ms/step - loss: 7.6815e-04
# Epoch 57/100
# 30/30 [==============================] - 2s 50ms/step - loss: 7.8813e-04
# Epoch 58/100
# 30/30 [==============================] - 2s 50ms/step - loss: 8.7688e-04
# Epoch 59/100
# 30/30 [==============================] - 2s 50ms/step - loss: 7.4353e-04
# Epoch 60/100
# 30/30 [==============================] - 2s 51ms/step - loss: 7.6387e-04
# Epoch 61/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0011
# Epoch 62/100
# 30/30 [==============================] - 2s 53ms/step - loss: 7.2619e-04
# Epoch 63/100
# 30/30 [==============================] - 2s 54ms/step - loss: 7.6947e-04
# Epoch 64/100
# 30/30 [==============================] - 2s 56ms/step - loss: 7.3214e-04
# Epoch 65/100
# 30/30 [==============================] - 2s 50ms/step - loss: 7.0232e-04
# Epoch 66/100
# 30/30 [==============================] - 2s 51ms/step - loss: 7.4404e-04
# Epoch 67/100
# 30/30 [==============================] - 2s 51ms/step - loss: 7.1840e-04
# Epoch 68/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.6412e-04
# Epoch 69/100
# 30/30 [==============================] - 2s 51ms/step - loss: 6.7752e-04
# Epoch 70/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.2771e-04
# Epoch 71/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.3586e-04
# Epoch 72/100
# 30/30 [==============================] - 2s 53ms/step - loss: 7.4820e-04
# Epoch 73/100
# 30/30 [==============================] - 2s 55ms/step - loss: 7.3259e-04
# Epoch 74/100
# 30/30 [==============================] - 2s 55ms/step - loss: 7.4048e-04
# Epoch 75/100
# 30/30 [==============================] - 2s 54ms/step - loss: 6.2239e-04
# Epoch 76/100
# 30/30 [==============================] - 2s 53ms/step - loss: 7.8570e-04
# Epoch 77/100
# 30/30 [==============================] - 2s 56ms/step - loss: 6.2869e-04
# Epoch 78/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.4476e-04
# Epoch 79/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.1037e-04
# Epoch 80/100
# 30/30 [==============================] - 2s 53ms/step - loss: 6.6489e-04
# Epoch 81/100
# 30/30 [==============================] - 2s 52ms/step - loss: 7.9271e-04
# Epoch 82/100
# 30/30 [==============================] - 2s 51ms/step - loss: 7.5663e-04
# Epoch 83/100
# 30/30 [==============================] - 2s 55ms/step - loss: 5.7616e-04
# Epoch 84/100
# 30/30 [==============================] - 2s 53ms/step - loss: 5.7586e-04
# Epoch 85/100
# 30/30 [==============================] - 2s 55ms/step - loss: 7.3257e-04
# Epoch 86/100
# 30/30 [==============================] - 2s 54ms/step - loss: 6.1251e-04
# Epoch 87/100
# 30/30 [==============================] - 2s 56ms/step - loss: 6.8490e-04
# Epoch 88/100
# 30/30 [==============================] - 2s 52ms/step - loss: 6.9859e-04
# Epoch 89/100
# 30/30 [==============================] - 2s 51ms/step - loss: 5.7331e-04
# Epoch 90/100
# 30/30 [==============================] - 2s 53ms/step - loss: 7.4171e-04
# Epoch 91/100
# 30/30 [==============================] - 2s 53ms/step - loss: 5.1837e-04
# Epoch 92/100
# 30/30 [==============================] - 2s 54ms/step - loss: 5.6388e-04
# Epoch 93/100
# 30/30 [==============================] - 2s 55ms/step - loss: 5.9268e-04
# Epoch 94/100
# 30/30 [==============================] - 2s 52ms/step - loss: 5.8966e-04
# Epoch 95/100
# 30/30 [==============================] - 2s 52ms/step - loss: 5.2724e-04
# Epoch 96/100
# 30/30 [==============================] - 2s 53ms/step - loss: 6.0290e-04
# Epoch 97/100
# 21/30 [====================>.........] - ETA: 0s - loss: 5.9791e-04
